# %%
from curves import shape_preserving_average_spline, max_smooth_interp
from datetime import date
import pandas as pd

# %%
shape_preserving_average_spline?

# %%
contracts = [
            (date(2019, 1, 2), date(2019, 1, 2), 32.7),
            (date(2019, 1, 3), date(2019, 1, 7), 29.3),
            (date(2019, 1, 8), date(2019, 1, 31), 24.66),
            (date(2019, 9, 1), date(2019, 9, 30), 25.66),
            (date(2019, 10, 1), date(2019, 10, 31), 24.66),
            (date(2019, 11, 1), date(2019, 11, 30), 25.66),
            (date(2019, 12, 1), date(2019, 12, 31), 27.66),
]

shape_preserved_spline = shape_preserving_average_spline(contracts, freq='D')
shape_preserved_spline
# Out:
# 2019-01-02    32.700000
# 2019-01-03    31.268930
# 2019-01-04    29.938877
# 2019-01-05    29.019033
# 2019-01-06    28.421097
#                 ...
# 2019-12-27    28.528240
# 2019-12-28    28.612379
# 2019-12-29    28.696906
# 2019-12-30    28.781801
# 2019-12-31    28.867042
# Freq: D, Length: 364, dtype: float64

# %%
# %matplotlib inline
shape_preserved_spline.plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
dir(shape_preserved_spline)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
monthly_curve = pd.Series(data=[25.53, 26.245, 24.9, 16.22, 16.01, 16.5], 
                          index=pd.period_range(start=pd.Period(year=2020, month=5, freq='M'), periods=6))
smooth_daily_curve = max_smooth_interp(monthly_curve, freq='D')
shape_preserved_curve = shape_preserving_average_spline(monthly_curve, freq='D')
smooth_daily_curve.plot()
shape_preserved_curve.plot()
# Out:
# <AxesSubplot:>
